# %%
# Import Library
import pickle
import pandas as pd

# Import Library ARIMA
import pickle

# Library Visualisasi
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
# Load Model Kategori A
with open('model_a.pkl', 'rb') as file_1:
  model_a = pickle.load(file_1)

# Load Model Kategori B
with open('model_b.pkl', 'rb') as file_2:
  model_b = pickle.load(file_2)

# Load Model Produk A1
with open('model_a1.pkl', 'rb') as file_3:
  model_a1 = pickle.load(file_3)

# Load Model Produk A2
with open('model_a2.pkl', 'rb') as file_4:
  model_a2 = pickle.load(file_4)

# Load Model Produk B1
with open('model_b1.pkl', 'rb') as file_5:
  model_b1 = pickle.load(file_5)

# Load Model Produk B2
with open('model_b2.pkl', 'rb') as file_6:
  model_b2 = pickle.load(file_6)

# %%
# Forecasting
model_a.forecast(35)
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 70     1600.807384
# 71     1611.702581
# 72     1618.680489
# 73     1626.542621
# 74     1633.396456
# 75     1640.301034
# 76     1708.890905
# 77     1659.637906
# 78     1670.619843
# 79     1677.450101
# 80     1685.261635
# 81     1692.021486
# 82     1698.846968
# 83     1767.009066
# 84     1718.463718
# 85     1729.532004
# 86     1736.219114
# 87     1743.981846
# 88     1750.649027
# 89     1757.395636
# 90     1825.131134
# 91     1777.284907
# 92     1788.439121
# 93     1794.987498
# 94     1802.703202
# 95     1809.279035
# 96     1815.947018
# 97     1883.257112
# 98     1836.101561
# 99     1847.341251
# 100    1853.755224
# 101    1861.425650
# 102    1867.911462
# 103    1874.501094
# 104    1941.387004
# ...

# %%
# Visualisasi Forecast
result_a = pd.DataFrame(model_a.forecast(35))
sns.lineplot(x=result_a.index, y=result_a.predicted_mean, data=result_a)
plt.title('Prediksi 35 hari')
plt.show()
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Forecasting
model_b.forecast(35)
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 85     5937.013782
# 86     5979.164122
# 87     6048.846960
# 88     6106.152746
# 89     6186.303321
# 90     6259.310003
# 91     6330.959342
# 92     6411.815431
# 93     6486.678709
# 94     6569.468156
# 95     6647.808498
# 96     6729.781150
# 97     6811.608107
# 98     6893.247645
# 99     6976.785245
# 100    7058.919151
# 101    7142.799721
# 102    7225.894631
# 103    7309.679569
# 104    7393.523142
# 105    7477.277080
# 106    7561.482162
# 107    7645.399346
# 108    7729.682741
# 109    7813.823546
# 110    7898.095657
# 111    7982.403700
# 112    8066.684979
# 113    8151.069882
# 114    8235.396034
# 115    8319.799046
# 116    8404.178096
# 117    8488.581833
# 118    8572.997863
# 119    8657.406971
# ...

# %%
# Visualisasi Forecast
result_b = pd.DataFrame(model_b.forecast(35))
sns.lineplot(x=result_b.index, y=result_b.predicted_mean, data=result_b)
plt.title('Prediksi 35 hari')
plt.show()
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Forecasting
model_a1.forecast(35)
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 70     183.759288
# 71     187.512997
# 72     187.880136
# 73     188.273226
# 74     188.129700
# 75     188.977576
# 76     202.614374
# 77     195.072920
# 78     197.379983
# 79     198.124750
# 80     198.567664
# 81     198.244764
# 82     199.577301
# 83     210.754010
# 84     205.902206
# 85     207.345792
# 86     208.306266
# 87     208.809162
# 88     208.426622
# 89     210.014300
# 90     219.295886
# 91     216.418609
# 92     217.379091
# 93     218.451993
# 94     219.017622
# 95     218.650831
# 96     220.345013
# 97     228.148740
# 98     226.716857
# 99     227.443769
# 100    228.572721
# 101    229.199964
# 102    228.896045
# 103    230.605265
# 104    237.242541
# Name: predicted_mean, dtype: float64

# %%
# Visualisasi Forecast
result_a1 = pd.DataFrame(model_a1.forecast(35))
sns.lineplot(x=result_a1.index, y=result_a1.predicted_mean, data=result_a1)
plt.title('Prediksi 35 hari')
plt.show()
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Forecasting
model_a2.forecast(35)
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 70     1417.802435
# 71     1424.852581
# 72     1431.881391
# 73     1438.924409
# 74     1445.990527
# 75     1453.113617
# 76     1505.258111
# 77     1467.406045
# 78     1474.564629
# 79     1481.671922
# 80     1488.777594
# 81     1495.921937
# 82     1503.155572
# 83     1555.424066
# 84     1517.705352
# 85     1525.008437
# 86     1532.242967
# 87     1539.480686
# 88     1546.782554
# 89     1554.220811
# 90     1606.712593
# 91     1569.234306
# 92     1576.788205
# 93     1584.256544
# 94     1591.725768
# 95     1599.277790
# 96     1607.000504
# 97     1659.782815
# 98     1622.595155
# 99     1630.433532
# 100    1638.149916
# 101    1645.846650
# 102    1653.625372
# 103    1661.591717
# 104    1714.606667
# ...

# %%
# Visualisasi Forecast
result_a2 = pd.DataFrame(model_a2.forecast(35))
sns.lineplot(x=result_a2.index, y=result_a2.predicted_mean, data=result_a2)
plt.title('Prediksi 35 hari')
plt.show()
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Forecasting
model_b1.forecast(35)
# Out:
# array([ 988.76605031,  977.37715151, 1111.38147368, 1143.57750857,
#        1130.35954453, 1107.17014516,  984.66286889, 1111.92427937,
#        1135.00974278, 1101.11663151, 1075.40920072,  983.21141112,
#         987.34379088,  975.97127409, 1109.78284196, 1141.93256547,
#        1128.7336144 , 1105.57757109,  983.24651156, 1110.32486687,
#        1133.37712372, 1099.53276493, 1073.86231218,  981.79714159,
#         985.92357726,  974.56741891, 1108.18650974, 1140.28998849,
#        1127.11002303, 1103.98728781,  981.83219154, 1108.72775499,
#        1131.74685305, 1097.95117661, 1072.31764872])

# %%
# Visualisasi Forecast
result_b1 = pd.DataFrame(model_b1.forecast(35), columns=['predicted_mean'])
sns.lineplot(x=result_b1.index, y=result_b1.predicted_mean, data=result_b1)
plt.title('Prediksi 35 hari')
plt.show()

# %%
# Forecasting
model_b2.forecast(35)
# Out:
# array([ 988.76605031,  977.37715151, 1111.38147368, 1143.57750857,
#        1130.35954453, 1107.17014516,  984.66286889, 1111.92427937,
#        1135.00974278, 1101.11663151, 1075.40920072,  983.21141112,
#         987.34379088,  975.97127409, 1109.78284196, 1141.93256547,
#        1128.7336144 , 1105.57757109,  983.24651156, 1110.32486687,
#        1133.37712372, 1099.53276493, 1073.86231218,  981.79714159,
#         985.92357726,  974.56741891, 1108.18650974, 1140.28998849,
#        1127.11002303, 1103.98728781,  981.83219154, 1108.72775499,
#        1131.74685305, 1097.95117661, 1072.31764872])

# %%
# Visualisasi Forecast
result_b2 = pd.DataFrame(model_b2.forecast(35), columns=['predicted_mean'])
sns.lineplot(x=result_b2.index, y=result_b2.predicted_mean, data=result_b2)
plt.title('Prediksi 35 hari')
plt.show()
